# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-E0ERQBN:4044">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
import tweepy as tw

# %%
sc.stop()

# %%
consumer_key="3fxfHchULcgRRtaPVWSRMRAmW"
consumer_secret="UPItL5fM67ZkGKfVmLIpngBb3fu7VBDliZCc3hPmZsXQRwypPp"
access_token="805480776074756097-2JX51bLZiSWol9yQFxIsYOLsI22BU3t"
access_secret="uhMMZ5uVfM26rwXPUNLx2xk9UmUDVeZPOXWHacjfori0P"

# %%
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api= tw.API(auth,wait_on_rate_limit =True)

# %%
search_words = "#olympic"
date_since = "2021-08-07"

# %%
tweets = tw.Cursor(api.search,q=search_words,lang="en",since=date_since).items(200)
#tweets = tw.Cursor(api.search, lang="en",since=date_since).items(20)
[tweet.text for tweet in tweets]
# Out:
# ['A fleeting observation. "Marco Polo" &amp; "cannonballs" are surprisingly apropos names for mostly male-initiated (all… https://t.co/z4SPW3ENdc',
#  'Pretty great day out: freshening up at Parliament Hill Lido, reclining on a #CharlottePerriand at @designmuseum, la… https://t.co/5WnHm4a0MA',
#  '#TokyoOlympics bronze medalist #LovlinaBorgohain said her dream is to win the #gold medal &amp; become an #Olympic cham… https://t.co/YET19Nka1X',
#  'RT @SmithsonianAPA: @smithsonian As the 2021 #Olympic surfers head to Tsurigasaki Beach, we honor the legacy of Hawaiian native Duke Paoa K…',
#  "RT @SolodovDmitry: #Lavrov: Slogan #WeWillROCYou [used to cheer up #Russia's Olympic sportsmen, teamed-up under name #ROC - Russian Olympic…",
#  "#Lavrov: Slogan #WeWillROCYou [used to cheer up #Russia's Olympic sportsmen, teamed-up under name #ROC - Russian Ol… https://t.co/A64fu34zIi",
#  "@UK51NGH Moreover, they are #Khalistan. We don't care.\nA total of 20-25 Sikhs (men and women) represented India at… https://t.co/MaoM476dLv",
#  "RT @ysjagan: Congratulations to @Neeraj_Chopra1, a serving soldier of Indian Army, who has made India proud by winning the nation's first-e…",
#  'RT @The_BMC: "Separating athletic prowess from inaccurate understandings of biology is essential to ensure that all people can enjoy &amp; comp…',
#  '“I tell my story because I want people to understand that sport saved my life,” says @YusraMardini. Read her inspir… https://t.co/eF362C9J9o',
#  'RT @CNBCTV18News: Catch 2-time #Olympic medal winner @Pvsindhu1 discuss the role &amp; importance of private partnerships with athletes and she…',
#  'RT @CNBCTV18News: Catch 2-time #Olympic medal winner @Pvsindhu1 discuss the role &amp; importance of private partnerships with athletes and she…',
#  "RT @SwissCognitive: Well, well, well 😉 Stunning results from our data-driven Olympic medal table predictions \n\n@ArtifactSwiss's predictions…",
#  'RT @WomensRightsTW: What does short hair do with #feminist?\n\nSouth Korean gold medal-winning #archer, An San’s short haircut has attracted…',
#  "RT @SwissCognitive: Well, well, well 😉 Stunning results from our data-driven Olympic medal table predictions \n\n@ArtifactSwiss's predictions…",
#  'RT @16Sreejesh: The smile define everything 💪🙏\n\n@Neeraj_chopra1 \n#history #gold #athletics #olympic #tokyo https://t.co/4rCZku4vny',
#  'Drones showed many extras!\n\n#olympic\n#Tokyo2020 \n#paris2024\n\nhttps://t.co/4lXKiObDa1',
#  'RT @AnxietyPath: #Beach #beachvolleyball #SiestaKey🏖️\n\n"#ThrowbackThursday"?\n"#WaybackWednesday"?\n(Im not any good at these #\'s😂)\n\nIf I was…',
#  'RT @jindadilkashmir: #Letapore &amp; #Pampore Army Camp extends warm greetings with sweets to all ranks of #CRPF on the occasion of their 83rd…',
#  'RT @PriyaScifi: #ManPower Vs #GirlPower Indian Men win 5-4 again Germany in Hockey bronze medal match.\n\n#Olympics \n#Olympicsindia \n#Olympic…',
#  'RT @UW_Inter: 2021 #Tokyo #Olympic games\n\n📌 New Olympic games\n📌 #Turkey and the #Olympics \n\nOp-ed by #CüneytAkalın\n\nhttps://t.co/TG0oe48hEV',
#  "RT @dna: #Tokyo2020Olympics: What is the connection between archery and K-pop group #TWICE's Tzuyu\n\n#TokyoOlympics2020 #Tokyo2020 #TokyoOly…",
#  'What would you get a gold medal in if it was an olympic event?\n\nI’d get a gold medal in collecting baby yodas. HAHA… https://t.co/XXzpNvSLqW',
#  'RT @16Sreejesh: The smile define everything 💪🙏\n\n@Neeraj_chopra1 \n#history #gold #athletics #olympic #tokyo https://t.co/4rCZku4vny',
#  'RT

#  'RT @Poorvika_Mobile: ஒரே Eventல ரெண்டு Gold | Emoji Show\n\nWatch now: https://t.co/reQPK3VEvP\n\n#PoorvikaMobilesTamil #PoorvikaMobiles #Poorv…']

# %%
new_search= search_words 
new_search
# Out:
# '#olympic'

# %%
tweets = tw.Cursor(api.search, q=new_search,lang="en",since=date_since).items(500)
users_details = [[tweet.user.screen_name,tweet.user.name,tweet.user.followers_count,tweet.user.verified]for tweet in tweets]
users_details
# Out:
# [['twoasianparents', 'The Parenting Asian America Project', 447, False],
#  ['melaniedbikes', 'Melanie D', 1552, False],
#  ['ymediagroup', 'ymediagroup', 480, False],
#  ['batmaneatsbabie', 'x - Nashville Assassins', 398, False],
#  ['adityapratapsri', 'Aditya Shrivastava', 1053, False],
#  ['SolodovDmitry', '𝑫𝒎𝒊𝒕𝒓𝒚 𝑺𝒐𝒍𝒐𝒅𝒐𝒗 🇷🇺', 641, False],
#  ['SubeSingh09', 'Sube Singh', 76, False],
#  ['Im_LN___', 'Lakshmi Narasimha Goud', 24, False],
#  ['DrBrighton4', 'Dr Brighton🇨🇺🇹🇿🇧🇸🇺🇸🇨🇵🇰🇪🇳🇱🇬🇧', 347, False],
#  ['muslimgirl', 'Muslim Girl', 41576, True],
#  ['BrandStoryboard', 'Storyboard', 14565, True],
#  ['ShibaniGharat', 'Shibani Gharat', 10552, True],
#  ['tobiaskintzel', 'Tobias Kintzel', 5178, False],
#  ['Denon_wing', 'PSCH', 6, False],
#  ['enilev', 'Eveline Ruehlin', 1574, False],
#  ['irfanzayn_', 'Irfan Zayn', 19, False],
#  ['heion_ni', 'ｍTIKO', 57, False],
#  ['miss__shah__', 'Shayzay', 45415, False],
#  ['ArunYad00000622', 'Arun Yadav', 2, False],
#  ['GSBorikar', 'G S Borikar', 155, False],
#  ['UW_Inter', 'United World', 915, False],
#  ['tobebetterrr_00', '∆: smileee', 2, False],
#  ['j_bon29', 'Jenn D. Young', 317, False],
#  ['Ananadu6', 'Ananadu', 68, False],
#  ['IthacaRetweet', '#twithaca Retweet', 300, False],
#  ['nikhilpoonia17', 'Nikhil Poonia', 4, False],
#  ['14850today', '14850 Today', 6024, False],
#  ['alex09dennis', 'Alex Dennis Münster', 36, False],
#  ['kishorech5', 'KKCH', 133, False],
#  ['ormedesmarais', 'Orme', 1336, False],
#  ['Anna_BooksUSA', 'Anna Lehmann', 19, False],
#  ['Hiraeth1962', 'Gareth Rowlands', 105, False],
#  ['iamsam7860', 'Sam 🇵🇰', 16, False],
#  ['Burrowsdrums', 'Jeff Burrows 🇨🇦', 4512, False],
#  ['LiamCahill2013', 'Liam Cahill', 11272, False],
#  ['Ankita71330649', 'av', 21, False],
#  ['CNBCTV18News', 'CNBC-TV18', 956915, True],
#  ['LiuZhaoyang5', '琵琶湖', 854, False],
#  ['masalafilmy', 'filmymasala', 142, False],
#  ['andykerrcarter', 'Andy Carter', 1348, False],
#  ['bonobtha', 'BONO', 506, False],
#  ['aerezona', 'کپتان کا سپاہی', 251, False],
#  ['TxUsjkJArpAflNc', '点の記', 300, False],
#  ['prakash_aravind',
#   'Prakash N- Sports Lover & follower from Namakkal',
#   213,
#   False],
#  ['asnningsih__', 'Iyou', 57, False],
#  ['bose_shohini', 'Shohini Bose', 192, False],
#  ['the6thdecade', 'LouiseP', 1193, False],
#  ['TheQuint', 'The Quint', 683593, True],
#  ['NineteenNinetz', '🎪', 296, False],
#  ['JackBaure24', 'JackBauer', 254, False],
#  ['KOJOINVOICE1', 'K O J O. I N V O I C E', 465, False],
#  ['TanyaRa24113643', 'Tanya Ray', 0, False],
#  ['WestphalErin', 'Erin Westphal', 500, False],
#  ['RekhaSo26869084', 'Rekha Soni', 0, False],
#  ['SumitRa54053782', 'Sumit Ray', 0, False],
#  ['rjanna_rose', 'proud Engineer RJᴬᵃʳⁱ ᴵⁿ ᴮᴬᴳᴬⱽᴬᴺ', 736, False],
#  ['owifowav', 'suzuki adamu', 1041, False],
#  ['calUSAwrestling', 'CAUSAWrestling', 4192, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1300, False],
#  ['SachinJ64974103', 'Sachin Jaiswal', 1, False],
#  ['yeshaa_always', 'India at 75 🇮🇳', 287, False],
#  ['KajalYa59912835', 'Kajal Yadav', 0, False],
#  ['vishwa_samvad', 'Vishwa Samvada Kendra', 9393, False],
#  ['live_seasons', 'PaTh', 12008, False],
#  ['udayveeryadav5', 'NCIB LAKHIMPUR KHERI', 94, False],
#  ['ToreSvenning', 'Tore Svenning', 207, False],
#  ['ETNOWlive', 'ET NOW', 680539, True],
#  ['MunnaLa28732267', 'Munna Lal Yadav', 1, False],
#  ['today_seniors', 'Seniors Today', 2114, False],
#  ['here_jagruk', 'Jagruk Hindustan', 802, False],
#  ['Prince_singh158', 'Prince_singh', 28, False],
#  ['davidsheldon95', 'David', 1816, False],
#  ['News9Tweets', 'News9', 28123, True],
#  ['ItikyalPs', 'SHO ITIKYAL PS', 15, False],
#  ['Rishiscribe', 'Rishikesh Bahadur D', 2039, False],
#  ['SanjayK40967216', 'Sanjay Kumar', 1, False],
#  ['Parthib70309892', 'Parthiban', 1, False],
#  ['Priyanka7645', '𝑷𝒓𝒊𝒚𝒂𝒏𝒌𝒂🇮🇳🚩', 337, False],
#  ['thehatandbeard', 'paul', 573, False],
#  ['donnyfarmshop',
#   '#Global Doncaster 🇬🇧 ✈️🚄 Lynn & The Farm Shop',
#   4116,
#   False],
#  ['bihariMARINERS', "MAD;';'●♤MARINER💚❤", 140, False],
#  ['Mnh00051937', 'จอยขายข้าวมันไก่', 23, False],
#  ['KevinLe18338408', 'Kamlesh Sharma.', 19, False],
#  ['_PrashamShah_', 'Prasham Shah', 13, False],
#  ['vnzyrtx', 'nca', 37, False],
#  ['RockySoibam', 'Soibam Rocky Singh', 1750, False],
#  ['tejjaggavarapu', 'Tejkumarreddy', 73, False],
#  ['durgeshpatel89', 'दुर्गेश पटेल', 10157, False],
#  ['nistula', 'Nistula Hebbar', 192505, True],
#  ['PJay2417', 'patel jay2417', 237, False],
#  ['the_hindu', 'The Hindu', 7131267, True],
#  ['Unbelted', 'Aashish Bansal', 921, False],
#  ['Tanveer75506628', 'Tanveer Shaikh', 1925, False],
#  ['rnadeau12', 'Robin', 669, False],
#  ['zhyty12', 'zakk16_', 38, False],
#  ['Nonco11087178', 'Nonco', 1296, False],
#  ['tnfmagazine', 'The New Feminist', 252, False],
#  ['Playing_Pasts',
#   'ℙ𝕝𝕒𝕪𝕚𝕟𝕘 ℙ𝕒𝕤𝕥𝕤🤼\u200d♀️⛹️\u200d♀️🤺🏊\u200d♂️🏏⛸🤸\u200d♂️',
#   1475,
#   False],
#  ['dasarathi37', 'Dasarathinayak', 118, False],
#  ['LilyCarel', 'lily', 339, False],
#  ['RositaDivna', 'Rosita 💙', 6666, False],
#  ['ManpreetGoldy33', 'Manpreet Singh Goldy', 377, False],
#  ['SaraRob84303004', 'Sara Robles', 82, False],
#  ['CNBCTV18News', 'CNBC-TV18', 956915, True],
#  ['SameerS74752437', 'Sameer Saifi', 1, False],
#  ['HelpNowIndia', 'HelpNow', 1028, True],
#  ['AO_Sports', 'AhramOnlineSports', 17411, False],
#  ['VadivelMahesh1', 'VadivelMahesh', 8, False],
#  ['CNBCTV18News', 'CNBC-TV18', 956915, True],
#  ['ISanthosh99', 'Santhosh', 39, False],
#  ['refa_buana', 'Refa Buana', 392, False],
#  ['Raja08627068', 'Raja', 0, False],
#  ['MadCrazyHatter_', 'Abhimanyu Mathur', 697, False],
#  ['Mammukkafanboy1', 'since696', 229, False],
#  ['wilkesy49', 'Graeme Wilkes', 1466, False],
#  ['Acenonooy', 'Acm', 2309, False],
#  ['RobustStory', 'Robust Story', 147, False],
#  ['SachinR53880172', 'Sachin Ram', 27, False],
#  ['link2arj', 'Arjun K', 13, False],
#  ['SILENCEISGOLDE', '🥰🥰🥰🥰🥰🥰BringHomeWithBeacon', 570, False],
#  ['ShagunS26055441', 'Shagun Sharma', 1, False],
#  ['NuclearFront', 'Nuclear power plant is front for atomic bomb.', 240, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['afifadefi', 'A F I F A', 1924, False],
#  ['goldmedalfamous', 'Gold Medal Famous', 1031, False],
#  ['Rshivi04', 'Shivanshi Singh Raghuvanshi', 26, False],
#  ['phumz_24', 'Phumelela Mbande • OLY', 1375, False],
#  ['GOProject_SA', 'Girls Only Project', 226, False],
#  ['Fecadu2', 'Fecadu', 210, False],
#  ['naoakisetuko', 'ますく&るる', 2902, False],
#  ['Fecadu2', 'Fecadu', 210, False],
#  ['abhishekov1', 'abhishek', 60, False],
#  ['i_ammvp', 'Mayur Pawar', 85, False],
#  ['annie_tee1', 'A Timoney', 30, False],
#  ['ShivA78904869', 'ShivA', 3, False],
#  ['Asifsnadaf2', 'ಆಸಿಫ್ ಎಸ್ ನದಾಫ್', 19, False],
#  ['Armani_or_Die', '👑Sporax•👑🇬🇭', 1127, False],
#  ['SocialNewsXYZ', 'SocialNews.XYZ', 475, False],
#  ['agk4444', '#Rajanna(G🌐pi AdusuⓂilli)', 349, False],
#  ['surajgowdafans1', 'surajgowdafansclub', 6, False],
#  ['maharashtra', 'Maharashtra🇮🇳', 3261, False],
#  ['MrBirdPhoto', 'Michael Bird', 204, False],
#  ['Priya65765668', 'Priya', 0, False],
#  ['mumbai_mitra', 'Daily MumbaiMitra', 76, False],
#  ['Dailyvruttmitra', 'Daily Vruttmitra', 297, False],
#  ['yagbebi', 'Yemmi Agbebi, MBA #BlackLivesMatter', 4852, False],
#  ['Babyolly4', 'dolphin', 1680, False],
#  ['syfrsyz', 'donut🇵🇸', 2393, False],
#  ['ElBronconator', 'J', 344, False],
#  ['ESPRIMO7', 'ESPRIMO＠ 江戸時代に戻ろう！\u3000Back to The Edo', 4745, False],
#  ['Amit_Raj_75', 'Amit Raj', 3, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['reubenbraham', 'Reuben Braham', 116, False],
#  ['BeyanNegisty', 'Negisty Beyan', 94, False],
#  ['livjr75', 'Moot&Academic', 58, False],
#  ['HistriaBooks', 'Histria Books', 1085, False],
#  ['RaajakumaraAppu', 'ಸಚಿನ್ (ಅಪ್ಪು❤)', 312, False],
#  ['BangaloreTimes1', 'Bangalore Times', 159801, True],
#  ['AshrafulGolam', 'A.I.M.Golam Rabbany', 38, False],
#  ['m_1926ai', 'まいまい🌟 ランニング女子', 495, False],
#  ['Heavensangel67', 'Tania🕊', 13657, False],
#  ['Heavensangel67', 'Tania🕊', 13657, False],
#  ['Wind_at_Dusk', '夕暮れの風🎗️台湾队🏅️', 279, False],
#  ['vishalwatts92', 'VISHAL WATTS', 103, False],
#  ['IshikaY57405179', 'Ishika Yadav', 2, False],
#  ['JaykumarBhamare', 'jaykumar bhamare', 6, False],
#  ['mumaralid', 'Mian Umar Ali', 753, False],
#  ['SportslightMed_', 'Sportslight Media', 72, False],
#  ['LH', 'Luke Hutchison', 3056, False],
#  ['asghkel', 'Asghkel', 40, False],
#  ['JChaiyasothi', 'Jarkkrrapobb Chaiyasothi', 104, False],
#  ['BourneNatural', 'BourneNaturalBeauty', 5323, False],
#  ['lodha_siddhi', 'Siddhi Lodha', 13, False],
#  ['gearing_up_mind', 'Gearing Up Mind', 1, False],
#  ['ramcosmartbuild', 'Ramco SmartBuild', 1437, False],
#  ['Cryptolab888', 'Cryptolab888', 244, False],
#  ['nrlsalihaa', 'ଘ˚𝒍𝒆𝒚𝒂˚✿', 54, False],
#  ['akemasyraf', 'Kemto', 580, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['okejuli', 'Eko Julianto', 278, False],
#  ['ridzuaaannn_', '🚀', 470, False],
#  ['apekshasandesh_', 'Apeksha Sandesh', 75, False],
#  ['HydTimes', 'Hyderabad Times', 57183, True],
#  ['So_ongDK', '𝘾𝙞𝙩𝙮 𝙇𝙞𝙜𝙝𝙩𝙨 Nobita', 296, False],
#  ['ieka93', 'HM', 5062, False],
#  ['MaCo_KaZ', 'KaZ@凛々', 737, False],
#  ['bwfmedia', 'BWF', 197013, True],
#  ['boysbyw', 'flandus', 3, False],
#  ['bhaswati10', 'Bhaswati Ghosh', 30656, False],
#  ['gonuguntlakish1', 'gonuguntla kishore', 7, False],
#  ['mathisanth', 'Mathisanth Kanagavel', 136, False],
#  ['jigyasu_aadmi', 'jigyasu aadmi', 31, False],
#  ['Cyient', 'Cyient', 19169, False],
#  ['dhavanyakalai', 'Dhavanyakalai', 0, False],
#  ['ranjitkumarTOI', 'Ranjit Kumar', 63, False],
#  ['s_subetha', 'Subetha S', 0, False],
#  ['rajuagn', 'RAJU MANDAL', 87, False],
#  ['Howl_India', 'Howl', 7, False],
#  ['Nameisrajanala', 'APGOTTHEBESTCM', 225, False],
#  ['yeshaa_always', 'India at 75 🇮🇳', 287, False],
#  ['DelhiTimesTweet', 'Delhi Times', 77813, True],
#  ['alleygator', 'Rodrigo Hunrichse', 1305, False],
#  ['doulthabad_ps', 'SHO_Doulthabad_PS', 372, False],
#  ['sooraj0222', 'SOORAJ0222', 5, False],
#  ['Chandon_Kala', 'Chandrakala P', 2373, False],
#  ['Jihad76381219', 'Jihad', 0, False],
#  ['are_akash', 'ARE AKASH SAI REDDY🔔', 389, False],
#  ['antony_naveen18', 'Antony Naveen', 45, False],
#  ['KUdhayavani', 'Kalamajiiraranjini Udhayavani', 34, False],
#  ['AmmarAlChalabi', 'Ammar Al-Chalabi', 3463, False],
#  ['nicephoebetiara', 'Blue Gardenia', 219, False],
#  ['ankushparihar32', 'Ankush Parihar', 3, False],
#  ['honey9834', 'Shashank Pandey 🇮🇳🕉️🚩🇮🇳🕉️🚩', 306, False],
#  ['PIBMumbai', 'PIB in Maharashtra 🇮🇳', 58934, True],
#  ['Jayasur41534375', 'Jayasurya', 6, False],
#  ['SuhaniSingh2021', 'Suhani Singh@2021', 1, False],
#  ['VoiceoftheBund', 'Voice of the Bund', 68, False],
#  ['subhanafnankha', 'Subhan Afnan khan', 53, False],
#  ['RomendraRajSin4', 'Romendra Raj Singh', 2, False],
#  ['shrishti_swaraj', 'Shrishti Swaraj', 28, False],
#  ['DanielA39318904', 'Daniel Aguayo', 15, False],
#  ['hkcd_HK', '香港商報', 66, False],
#  ['KasaniVeeresh', 'Veeresh Kasani', 574, False],
#  ['super_gamejin3', '【サッカー好きな】唯のゲーマー', 1, False],
#  ['TODDCastPodcast', 'Todd Hancock', 8422, False],
#  ['venugopalgali', 'Venu Gopal Gali', 5, False],
#  ['vivek_web', 'vivek pandey विवेक', 1311, False],
#  ['Jayanth17656566', 'Nomula Jayanth yadav', 29, False],
#  ['thebulletinbox', 'The Bulletin Box', 22, False],
#  ['ETNOWlive', 'ET NOW', 680539, True],
#  ['NIwJ5vwLxxtzrg7', '五輪生(iwao)', 82, False],
#  ['ct_latha', 'Latha CT', 6, False],
#  ['nitish_0087', 'nitish panwar', 0, False],
#  ['ApexFitzone', 'Apex FitZone', 7, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['sudheeshu', 'Sudheesh U', 130, False],
#  ['jeetbuzz', 'Jeetbuzz', 89, False],
#  ['Sateeshkumar965', 'Sathish Kumar', 3, False],
#  ['bharathkibeti', 'Devashree 🖤', 3106, False],
#  ['bharathkibeti', 'Devashree 🖤', 3106, False],
#  ['BradHast', 'Brad Hast', 479, False],
#  ['kokushokucom', '穀食.com（テレパシー情報屋）', 266, False],
#  ['kaguike', 'K.SoeTa（脱原発に一票）', 714, False],
#  ['morinosekai1414', 'なるみ👒期間限定🎐納涼アイコン(笑)🍧残暑お見舞い申し上げます🍉', 2270, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['FitEkaOc', 'bbyu(L)', 159, False],
#  ['6z_p1', 'ハルの子', 88, False],
#  ['tv9gujarati', 'tv9gujarati', 654300, True],
#  ['ZEE5News', 'ZEE5 News', 34146, True],
#  ['minervaowl_fly', 'Minerva owl', 2149, False],
#  ['8four25jr', '8four25', 146, False],
#  ['mezzobureaucrat', 'Jen J Harewood', 176, False],
#  ['Url4Ever', 'URL4EVER', 23, False],
#  ['narendra_garre', 'Garre Narendra', 178, False],
#  ['narendra_garre', 'Garre Narendra', 178, False],
#  ['FDNYWomen', 'FDNY Women', 2659, False],
#  ['2viciouzC', 'C3ViCiouZ', 16, False],
#  ['SweetCookiesme', 'Arvind', 625, False],
#  ['imAnkeshanand', '#Stay_Home #Stay_Safe 🇮🇳', 218, False],
#  ['Pamela84036781', 'Pamela', 21, False],
#  ['Tanya_Sinclair', 'Tanya Sinclair, CHRE 🇨🇦 🇯🇲', 326, False],
#  ['Corona_SSYT', 'Corona Virus Updates', 2599, False],
#  ['pchopner', 'Paulo Cesar Hopner🇧🇷🏴🐕🔰🌳🌲☘', 3312, False],
#  ['MacalusoJoseph', 'Joseph N Macaluso MD FACS', 1814, False],
#  ['LightspeedSteps', 'Lightspeed', 977, False],
#  ['AdamKarbowski', 'Adam Karbowski', 156, False],
#  ['LCoxMPH', 'Lisa Cox PR', 80, False],
#  ['Afterstorm13', 'Afterstorm', 1030, False],
#  ['SportBC', 'Sport BC', 6887, False],
#  ['41OPP', 'Seán Browne', 151, False],
#  ['jamiehansman', 'Jamie Hansman', 228, False],
#  ['JackBaure24', 'JackBauer', 254, False],
#  ['NicolaeCoj373', 'Nicolae Cojocaru', 2, False],
#  ['RobertLanex', 'Robert Lane', 1, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1300, False],
#  ['Dragofix', 'Dragofix', 4407, False],
#  ['sfischer2010', 'S Fischer', 8663, False],
#  ['sfischer2010', 'S Fischer', 8663, False],
#  ['TodoSports2021', 'Everything Sports', 154, False],
#  ['MimiSayani', 'Shershaah FTW', 1715, False],
#  ['ServerlessFan', 'Serverless Fan', 3692, False],
#  ['JackBaure24', 'JackBauer', 254, False],
#  ['pupijunkul', 'chris⁷ 🍀 | BEcause 🎠', 1270, False],
#  ['PoetOrganic', 'The Organic Poet', 1493, False],
#  ['Nasrull30828303', 'Nasrullah', 1855, False],
#  ['TheSugarMan__', 'ALPHA🧢H.V.M🐺📌', 7016, False],
#  ['Prepsyboard', 'Prepsy', 2, False],
#  ['WESmith91', 'William E. (Bill) Smith', 1034, False],
#  ['robynlisaflynn', 'Robyn Flynn', 5302, False],
#  ['Macaco30301', 'Macaco3030', 28, False],
#  ['CMFSC', 'Coquitlam Metro-Ford SC', 337, False],
#  ['AdeleScorpions', 'Adele Deakes', 581, False],
#  ['ServerlessFan', 'Serverless Fan', 3692, False],
#  ['JackBaure24', 'JackBauer', 254, False],
#  ['pmnorm', 'Dr. Woody/Carpenter Girl', 3224, False],
#  ['ServerlessFan', 'Serverless Fan', 3692, False],
#  ['BonjourKampala', 'Bonjour Kampala', 543, False],
#  ['VandanaThapa3', 'Vandana Thapa', 120, False],
#  ['goodeywrites', 'S. Goodey', 322, False],
#  ['__awitadeuwu__', 'Emilia PM', 25, False],
#  ['Alonso15922455', 'Alonso', 960, False],
#  ['dheeraj_miet', 'Dheeraj Verma', 96, False],
#  ['BaHARsanals', 'BaHARr ///___', 136, False],
#  ['Candelacata1', 'Candelacata1', 64, False],
#  ['miina0619', 'みいポリン☆', 73, False],
#  ['RealSamimAktar', 'Samim Aktar', 5327, False],
#  ['IrPsych', 'Carole (Ducky)', 4010, False],
#  ['NameeeeNice', 'Efua....❤️🇬🇭', 3699, False],
#  ['JijoTho85007776', 'Jijo Thomas', 3, False],
#  ['mycool015', 'ゆーき', 664, False],
#  ['JapanCons_vanc', '在バンクーバー日本国総領事館', 4289, True],
#  ['dn_rath', 'dn.rath@gmail.com', 481, False],
#  ['Wrestlingcardk1', 'Rob England', 606, False],
#  ['RumaRaj2', 'Ruma Raj', 1, False],
#  ['CHRISCERRONI', 'Chris Cerroni MSc', 597, False],
#  ['PwH4Iut68HeW4GX', 'زهراء العلي', 711, False],
#  ['ano_ha', 'あのはな', 54, False],
#  ['anandkhatod8', 'आनंदकुमार खटोड', 26, False],
#  ['RamireddyBommi1', 'Ramireddy Bommireddy', 84, False],
#  ['virajsw', 'Viraj suwasiya', 13, False],
#  ['tphfamily', 'TPH', 272, False],
#  ['Keremela12', 'Keremela', 0, False],
#  ['garbett_stephen', 'Stephen Garbett', 629, True],
#  ['HariomVhp', 'हरिओम राजावत विहिप #प्रशासक_समिति', 1826, False],
#  ['casanor11', 'NatteramnGjenferd', 541, False],
#  ['masoom_anw', 'Masoom Anwar', 2, False],
#  ['GsLessons', 'DrGsHistoryLessons', 14, False],
#  ['Anurag73916381', 'Anurag', 13, False],
#  ['aepedia', '🅰️3️⃣🅿️🇵🇱🇵🇸', 70, False],
#  ['efbman', '🇮🇪 Éanna 🐾🇪🇺🇵🇸🏳️\u200d🌈🥊🏉⚽️', 1572, False],
#  ['jules878', 'Julia Palmer', 349, False],
#  ['NLIreland', 'National Library of Ireland', 42042, False],
#  ['livingstonfinan', 'Peter Livingston', 1474, False],
#  ['FGM166', 'Faisal', 152, False],
#  ['Rimjhimsen12', 'Rimjhim sen', 6, False],
#  ['juliebabyar', 'Julie Babyar', 9681, False],
#  ['janbarstad', 'janbarstad', 6665, False],
#  ['PANKAJT1001', 'PANKAJ THAKARE', 60, False],
#  ['hemanth1981998', 'Hém@ñțh', 588, False],
#  ['duxfemfac', "La'Tasha D. Mayes", 2967, False],
#  ['thenewshooked', 'TheNewsHOOK', 1284, False],
#  ['bcsoccerweb', 'BCSoccerWeb.com', 2401, False],
#  ['PradeepYdv20', 'Pradeep yadav', 2102, False],
#  ['juliebabyar', 'Julie Babyar', 9681, False],
#  ['AryaGow24804227', 'Arya Gowda', 0, False],
#  ['BoldProfitDaily', 'Bold Profits Daily', 3250, False],
#  ['amitshah_MH09', '🇮🇳 Amit Shah, Kolhapur, Bharat 🇮🇳', 394, False],
#  ['DasiKrsna', 'Lipsa (krsna Dasi)', 421, False],
#  ['DevDasRathore1', 'Dev Das (SHERSHAAH)', 199, False],
#  ['ponsharan', 'Pon Saravanan', 228, False],
#  ['Amalia13325296', 'Amalia', 33, False],
#  ['girija_achary', 'Girija Acharya', 53, False],
#  ['shaunwillo90', 'Shaun Williams', 424, False],
#  ['mikemeidling', 'Mike M.', 934, False],
#  ['MMAFighting', 'MMAFighting.com', 617769, True],
#  ['Creaform', 'Creaform', 3448, False],
#  ['shyam_kit', 'shyam', 20, False],
#  ['Barketalikhan41', 'Barketalikhan4589@gmail.Com', 5, False],
#  ['ABHINAV53292443', 'ABHINAV JHA', 53, False],
#  ['TechnoFails', 'Anykey', 9363, False],
#  ['TigerManjeet1', 'Tiger Manjeet', 0, False],
#  ['nandhu1512', 'Nandhakumar', 305, False],
#  ['SunilDravidan', 'Sunil Dravidan (திராவிடன்)', 1017, False],
#  ['sharonlinapearc', 'Sharon Lina Pearce', 989, False],
#  ['SekharB76486652', 'Sekhar Biswas', 42, False],
#  ['abdsamad', 'abdussamad', 67, False],
#  ['Rkchaupal2004', 'Ramdhari kumar', 1, False],
#  ['orlando300121', 'orlando matsota', 3, False],
#  ['alvinfoo', 'Alvin Foo', 71969, False],
#  ['1BCSoccer', 'BC Soccer', 6631, False],
#  ['ConesPinniespod', 'Cones&PinniesPod', 119, False],
#  ['Adamson63309869', 'Adamsons', 715, False],
#  ['carleton_douse', 'carleton douse', 14, False],
#  ['enterskills_i', 'Desiré Mutumba', 2306, False],
#  ['shasiri17', 'Shirisha', 83, False],
#  ['DharmaT45762805', 'Dharma Teja', 51, False],
#  ['GemsDawson', 'Gemma Dawson', 3540, False],
#  ['SMKN7Ska', 'Official account SMK N 7 Surakarta', 136, False],
#  ['johnekennett', 'John E. Kennett', 342, False],
#  ['alvinfoo', 'Alvin Foo', 71969, False],
#  ['ghssorg', 'Green Heart Springs', 27, False],
#  ['AbdoulR37230833', 'Abdoul Razack Karimou Ousmane', 538, False],
#  ['Yashkrizz', 'Yash', 793, False],
#  ['Yashkrizz', 'Yash', 793, False],
#  ['Yashkrizz', 'Yash', 793, False],
#  ['Yashkrizz', 'Yash', 793, False],
#  ['AshrafAliSyed3', 'ASHRAF YSRCP', 7, False],
#  ['nagar_jha', 'Nishant Nagar Jha', 8, False],
#  ['WestphalErin', 'Erin Westphal', 500, False],
#  ['RajowarAnimesh', 'ANIMESH RAJOWAR', 0, False],
#  ['Jing85919405', 'Jing', 56, False],
#  ['Praveen74833933', 'Praveen Kumar', 75, False],
#  ['AjeethK40221698', 'Ajeeth Kumar', 18, False],
#  ['flerlagekr', 'Ken Flerlage', 9662, False],
#  ['Chintan35610572', 'Chintan Thakor', 6, False],
#  ['Schreids', 'Michaela Schreiter', 3420, False],
#  ['Malamute_Dad', "Budzo's Dad 🌍🌲🏳️\u200d🌈🇺🇸", 125, False],
#  ['ManiacBridge', 'Bridge Maniac', 536, False],
#  ['emefen_', '.E M E F E N.', 452, False],
#  ['Back_in_Action', 'Dr Ian Horsley', 9149, False],
#  ['Rohit00484461', 'रोहित 🕉️🚩', 1231, False],
#  ['WestphalErin', 'Erin Westphal', 500, False],
#  ['WestphalErin', 'Erin Westphal', 500, False],
#  ['robynlisaflynn', 'Robyn Flynn', 5302, False],
#  ['aerezona', 'کپتان کا سپاہی', 251, False],
#  ['THEFREEMEDIA2K', 'THE FREE MEDIA', 58, False],
#  ['josephfelix210', 'Joseph Felix', 329, False],
#  ['pdpsingha', 'Pradeep', 1228, False],
#  ['KumarNavakumar', 'Navakumar Kumar Rabha', 0, False],
#  ['asancetta', 'Amy Sancetta', 930, True],
#  ['_Sai_Turlapati_', '__Sai Turlapati__', 19, False],
#  ['Gowtham09941970', 'Gowtham', 3, False],
#  ['Paaruu88', 'Itz_paaruu_88', 0, False],
#  ['Opoyis', 'Opoyi', 11380, False],
#  ['JigyanshuPande5', 'Jigyanshu Pandey', 14, False],
#  ['JGeeEleven', 'JGee', 16, False],
#  ['IvettAlexa', 'Kovács Ivett', 2931, False],
#  ['fernanadez99', 'Daniel John', 11, False],
#  ['paavan_anakin', 'Paavan', 67, False],
#  ['shamindraghosh1', 'shamindra ghosh', 31, False],
#  ['iamYugal18', 'Yugal Chambhare', 481, False],
#  ['AppleReddy7', 'sandhyareddy', 8, False],
#  ['the_hindu', 'The Hindu', 7131273, True],
#  ['TheHinduSports', 'The Hindu - Sports', 48020, True],
#  ['Khushbo46652613', 'Khush💥', 277, False],
#  ['tutuhead4', 'Michael Smith', 147, False],
#  ['sportpsychmind', 'Dr. Chelsi Day', 1864, False],
#  ['PeteOlusoga', 'Dr Peter Olusoga', 14556, False],
#  ['EPMPodcast', 'EightyPercentMental', 1929, False],
#  ['IsaacCopenhave3', 'El Potato', 297, False],
#  ['hiroko_7788', 'Hiro REDTaylorsVersion 🧣', 21855, False],
#  ['sangi_91', 'Sadanand patel', 7, False],
#  ['MohitKu45550608', 'Mohit Kumar', 7, False],
#  ['Sachibiswal092', 'Sachidananda Biswal', 9, False],
#  ['SDebasisIndian', 'S Debasis', 39, False],
#  ['thecovidsite', 'COVID News', 3294, False],
#  ['KyleOlbert', 'K. Olbert', 15838, False],
#  ['SmartDhyana', 'Dhyana', 122, False],
#  ['NamanAr22280575', 'Er. Naman Arora🇮🇳', 84, False],
#  ['garsampath', 'G.A.R. Sampath', 116, False],
#  ['vnzyrtx', 'nca', 37, False],
#  ['whatrtheoptions', 'Lindsey Galley', 33, False],
#  ['CSomnianti', 'CaveatSomnianti', 136, False],
#  ['RashmiV31194895', 'Rashmi Verma', 17, False],
#  ['sallypenni1', 'Sally Penni MBE🐝🐝 (She/Her)', 5149, False],
#  ['ImtiazGul60', 'Imtiaz Gul', 63149, False],
#  ['maybenadi02', 'Nadi 🦋', 31852, False],
#  ['AKNarne', 'అమరావతి; విశాఖ ఉక్కు - ఆంధ్రుల హక్కు 💪', 2602, False],
#  ['befriendings', 'Clive Lawrinson', 2169, False],
#  ['prakash_aravind',
#   'Prakash N- Sports Lover & follower from Namakkal',
#   213,
#   False],
#  ['AnilGou53184667', 'AniL_GoUd', 1, False],
#  ['das_sharu', 'Sharu Das', 2015, False],
#  ['SeithHasnainali', 'Hasnain Ali', 49, False],
#  ['iMiFpgC0xz4hGdj', 'ኤረትራ ዋጋ ስዉእ,ያ', 25, False],
#  ['itschandany', 'CHANDAN', 490, False],
#  ['KeBillion', 'Missionary ♀️', 845, False],
#  ['teachedison', 'TeachEdison', 125, False],
#  ['theedisonos', 'EdisonOS', 14, False],
#  ['DevoteeYs', 'Ys Jagan Devotee', 1, False],
#  ['neeraj_choyal', 'Neeraj Choyal', 31, False],
#  ['RatnakarKrishn1', 'Ratnakar', 411, False],
#  ['AkashMk24520486', 'Akash Mk', 7, False],
#  ['AyuTriwn', 'pengabdiwifi', 847, False],
#  ['missartola', 'smita mishra 🇮🇳', 5367, False],
#  ['crownchronicles', 'The Crown Chronicles', 9775, False],
#  ['CricGorgeous', 'Mahi', 152, False],
#  ['BotMobilegame', 'Mobile Game Bot', 425, False],
#  ['KishanMaiyad', 'KRUSHNAM', 46, False],
#  ['MyLife_Congress', 'I Am Being Human 💕🖐💕', 3528, False],
#  ['PavanKu19517349', 'PAVAN KUMAR PRAJAPTI', 9, False],
#  ['chomsessentials', 'Chomsessentials', 57, False],
#  ['RFYouthSports', 'RF Youth Sports', 4919, True],
#  ['Nitish84984891', 'Nitish', 4, False],
#  ['velvetangels17', 'Sofia⁷≷ (fan.acc)✨🍒', 837, False],
#  ['SalemDinesh12', 'Salem Dinesh', 4, False],
#  ['JustAsk46082871', 'Just Asking', 41, False],
#  ['GtwoRath', 'Jitu', 233, False],
#  ['donaldhussle', 'Donaldhussle', 859, False],
#  ['ccitraandini', 'Citra Andini 🌙✨', 156, False],
#  ['GulrezShagufa', 'Shagufa Khan', 20, False],
#  ['Khanji61685240', 'Khanji', 1392, False],
#  ['MitraDebu1', 'MitraDebu', 26, False],
#  ['indianposten', 'indianposten', 461, False],
#  ['ABKPE', 'Alderbrook School PE', 261, False],
#  ['ThePEpodcast_', 'The PE Podcast', 66, False],
#  ['HaeSoo23', 'Hae Soo', 249, False],
#  ['hi_dstaeri', 'ᮓᮨᮞ᮪ᮒᮢᮤ', 264, False],
#  ['Andriyan_syahh', 'Andriyansyah Unan', 717, False],
#  ['Rahul90431108', 'Rahul', 51, False],
#  ['BlackArrowsBC', 'Black Arrows', 263, False],
#  ['thebulletinbox', 'The Bulletin Box', 22, False],
#  ['BickyDa96697382', 'Bicky Das', 19, False],
#  ['YordaBerhane', 'Yordanos', 15, False]]

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
schema = StructType([ \
    StructField("Username",StringType(),True), \
    StructField("Name",StringType(),True), \
    StructField("Followers_count", IntegerType(), True), \
    StructField("Verified", StringType(), True) \
  ])
 
df = spark.createDataFrame(data=users_details,schema=schema)
#df.printSchema()
#df.show(truncate=False)
df.where(df.Verified == "true").show()
# Out:
# +---------------+--------------------+---------------+--------+
# |       Username|                Name|Followers_count|Verified|
# +---------------+--------------------+---------------+--------+
# |     muslimgirl|         Muslim Girl|          41576|    true|
# |BrandStoryboard|          Storyboard|          14565|    true|
# |  ShibaniGharat|      Shibani Gharat|          10552|    true|
# |   CNBCTV18News|           CNBC-TV18|         956915|    true|
# |       TheQuint|           The Quint|         683593|    true|
# |      ETNOWlive|              ET NOW|         680539|    true|
# |    News9Tweets|               News9|          28123|    true|
# |        nistula|      Nistula Hebbar|         192505|    true|
# |      the_hindu|           The Hindu|        7131267|    true|
# |   CNBCTV18News|           CNBC-TV18|         956915|    true|
# |   HelpNowIndia|             HelpNow|           1028|    true|
# |   CNBCTV18News|           CNBC-TV18|         956915|    true|
# |BangaloreTimes1|     Bangalore Times|         159801|    true|
# |       HydTimes|     Hyderabad Times|          57183|    true|
# |       bwfmedia|                 BWF|         197013|    true|
# |DelhiTimesTweet|         Delhi Times|          77813|    true|
# |      PIBMumbai|PIB in Maharashtr...|          58934|    true|
# |      ETNOWlive|              ET NOW|         680539|    true|
# |    tv9gujarati|         tv9gujarati|         654300|    true|
# |       ZEE5News|           ZEE5 News|          34146|    true|
# +---------------+--------------------+---------------+--------+
# only showing top 20 rows
